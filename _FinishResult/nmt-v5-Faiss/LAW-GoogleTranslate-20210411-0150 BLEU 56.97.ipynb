# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/Shared drives/chinh-share/nmt-v5-Faiss/'
os.chdir(path)
import time
FOLDERNAME = "LAW-GoogleTranslate-" + str(time.strftime("%Y%m%d-%H%M"))
# !mkdir $FOLDERNAME

path = path + FOLDERNAME
os.chdir(path)
# !pwd

# import os
# path = '/content/drive/Shared drives/chinh-share/nmt-v3/OpenNMT-TED-EM-bert-ratio-8-2-2-20210128-0637'
# os.chdir(path)
# !pwd
# Out:
# /content/drive/Shared drives/chinh-share/nmt-v5-Faiss/LAW-GoogleTranslate-20210411-0150

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# ## **Install libraries**

# %%
# !wget https://raw.githubusercontent.com/hoangtrungchinh/clc_data/master/law.tar.gz
# !mkdir data_bin
# !tar -xvf 'law.tar.gz' -C data_bin
# Out:
# --2021-04-11 01:50:25--  https://raw.githubusercontent.com/hoangtrungchinh/clc_data/master/law.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 988814 (966K) [application/octet-stream]
# Saving to: ‘law.tar.gz’
#
# law.tar.gz          100%[===================>] 965.64K  --.-KB/s    in 0.08s
#
# 2021-04-11 01:50:26 (11.5 MB/s) - ‘law.tar.gz’ saved [988814/988814]
#
# _law.vi
# _law.en

# %%
# !pip install translatepy
# Out:
# Collecting translatepy
#   Downloading https://files.pythonhosted.org/packages/08/40/2907020fdf155df493e3cd116a1b6b299216830c337c29781b9f64ed7f31/translatepy-1.5.2-py3-none-any.whl (310kB)
#      |████████████████████████████████| 317kB 5.6MB/s
# Collecting safeIO>=1.2
#   Downloading https://files.pythonhosted.org/packages/23/2f/00e4f435cc49f1b600807356e17ec7625f011a5ae86d8b893ab8ddb5bd98/safeIO-1.2.tar.gz
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from translatepy) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from translatepy) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->translatepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->translatepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->translatepy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->translatepy) (2.10)
# Building wheels for collected packages: safeIO
#   Building wheel for safeIO (setup.py) ... done
#   Created wheel for safeIO: filename=safeIO-1.2-cp37-none-any.whl size=6747 sha256=d0d78e522e9b407066d24dfbcf2b2df7f0574b127df0e56c633ad0a1741eceb1
#   Stored in directory: /root/.cache/pip/wheels/31/45/d9/677e5afdcffeb0bcbb4accaa6720868f53b6cdd80486e2539b
# Successfully built safeIO
# Installing collected packages: safeIO, translatepy
# Successfully installed safeIO-1.2 translatepy-1.5.2

# %%
import translatepy
translator = translatepy.Translator()
res = translator.translate("Hello", "vi")
print(res.result)
# Out:
# xin chào

# %%
import numpy as np
import glob

en_files = sorted(glob.glob("data_bin/*.en"))
vi_files = sorted(glob.glob("data_bin/*.vi"))
print(en_files)
print(vi_files)

lst_en = []
lst_vi = []

start = time.time()

for file in en_files:
  with open(file) as file_in:
    for line in file_in:
      lst_en.append(line)

for file in vi_files:
  with open(file) as file_in:
    for line in file_in:
      lst_vi.append(line)

print(len(lst_en))
print(len(lst_vi))
# Out:
# ['data_bin/_law.en']
# ['data_bin/_law.vi']
# 17967
# 17967

# %%
# SPLIT TRAIN, TEST, VALID
from sklearn.model_selection import train_test_split
en_train, en_test_valid, vi_train, vi_test_valid =  train_test_split(lst_en, lst_vi, test_size=0.2, random_state=123)
en_valid, en_test, vi_valid, vi_test = train_test_split(en_test_valid, vi_test_valid, test_size=0.5, random_state=123)
print(len(en_train))
print(len(vi_train))
print(len(en_valid))
print(len(vi_valid))
print(len(en_test))
print(len(vi_test))
print(en_train[20])
print(vi_train[20])
print(en_valid[-1])
print(vi_valid[-1])
print(en_test[-1])
print(vi_test[-1])
# Out:
# 14373
# 14373
# 1797
# 1797
# 1797
# 1797
# A person aged from fifteen years to below eighteen years may be an authorized representative, except where the law provides for that the civil transaction must be entered into and performed by a person who has reached eighteen years of age.
#
# Người từ đủ mười lăm tuổi đến chưa đủ mười tám tuổi có thể là người đại diện theo uỷ quyền, trừ trường hợp pháp luật quy định giao dịch dân sự phải do người từ đủ mười tám tuổi trở lên xác lập, thực hiện.
#
# The Law on Bankruptcy is applied to the bankruptcy process of every enterprise and cooperative based in the territory of Vietnam.
#
# Luật Phá sản được áp dụng khi giải quyết phá sản đối với doanh nghiệp, hợp tác xã được thành lập trên lãnh thổ Cộng hòa xã hội chủ nghĩa Việt Nam.
#
# A lawsuit is instituted over an administrative decision or act of a provincial-level People’s Committee or provincial-level People’s Committee chairperson which is related to many subjects;
#
# Khiếu kiện quyết định hành chính, hành vi hành chính của Ủy ban nhân dân cấp tỉnh, Chủ tịch Ủy ban nhân dân cấp tỉnh liên quan đến nhiều đối tượng;

# %%
file_variable = [en_train,vi_train,en_valid,vi_valid,en_test,vi_test]
file_names = ["en_train","vi_train","en_valid","vi_valid","en_test","vi_test"]

for i in range(len(file_names)):
  with open(file_names[i], 'w') as f:
    for item in file_variable[i]:
      f.write(item)
# !ls -al
# Out:
# total 6655
# drwx------ 2 root root    4096 Apr 11 01:50 data_bin
# -rw------- 1 root root  257314 Apr 11 01:50 en_test
# -rw------- 1 root root 2096540 Apr 11 01:50 en_train
# -rw------- 1 root root  265528 Apr 11 01:50 en_valid
# -rw------- 1 root root  988814 Apr 11 01:50 law.tar.gz
# -rw------- 1 root root  314903 Apr 11 01:50 vi_test
# -rw------- 1 root root 2560025 Apr 11 01:50 vi_train
# -rw------- 1 root root  325494 Apr 11 01:50 vi_valid

# %%
lst_translated = []
for i in range(len(en_test)):
  res = translator.translate(en_test[i], "vi")
  lst_translated.append(res.result)

# %%
with open("predict.txt", 'w') as f:
  for item in lst_translated:
    f.write(item)
    f.write("\n")

# %%
# !tail predict.txt
# Out:
# Trách nhiệm của cơ quan, tổ chức, cá nhân trong việc giải quyết tranh chấp lao động
# Việc kiểm tra giám định sẽ được thực hiện bởi các cá nhân hoặc một nhóm người.
# Bầu, miễn nhiệm, bãi nhiệm Chủ tịch Hội đồng thành viên; quyết định bổ nhiệm, miễn nhiệm, cách chức, ký và chấm dứt hợp đồng với Giám đốc hoặc Tổng giám đốc, Kế toán trưởng và người quản lý khác quy định tại Điều lệ công ty;
# Người yêu cầu Tòa án Việt Nam công nhận và cho thi hành hoặc không công nhận tại Việt Nam bản án, quyết định dân sự của Tòa án nước ngoài; hoặc để công nhận và thi hành phán quyết của trọng tài nước ngoài phải nộp lệ phí theo quy định của pháp luật Việt Nam.
# Họ, tên Thẩm phán, Thư ký Tòa án, Kiểm sát viên; họ, tên Thẩm phán, Kiểm sát viên dự khuyết (nếu có);
# Giới hạn trách nhiệm đối với bất kỳ người cứu hộ nào không hoạt động từ bất kỳ con tàu nào hoặc đối với bất kỳ người cứu hộ nào chỉ hoạt động trên con tàu hoặc đối với người đó thực hiện dịch vụ cứu hộ, sẽ được tính theo trọng tải 1.500 GT.
# Phương thức giải quyết tranh chấp.
# Thực hiện các nhiệm vụ, quyền hạn khác trong kiểm sát hoạt động tư pháp theo quy định của Bộ luật tố tụng hình sự.
# Chi phí sản xuất hàng giả từ 100.000.000 đồng trở lên;
# Khởi kiện đối với quyết định, hành vi hành chính của Ủy ban nhân dân cấp tỉnh, Chủ tịch Ủy ban nhân dân cấp tỉnh có liên quan đến nhiều đối tượng;

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 17114 (delta 8), reused 11 (delta 4), pack-reused 17082
# Receiving objects: 100% (17114/17114), 273.03 MiB | 15.70 MiB/s, done.
# Resolving deltas: 100% (12332/12332), done.
# Checking out files: 100% (228/228), done.

# %%
# !perl OpenNMT-py/tools/multi-bleu.perl vi_test < predict.txt
# Out:
# BLEU = 56.97, 78.9/64.9/54.1/46.1 (BP=0.953, ratio=0.954, hyp_len=48940, ref_len=51293)
