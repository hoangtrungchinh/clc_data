# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = ""
path = '/content/drive/Shared drives/chinh-share/nmt-v5-Faiss/'
os.chdir(path)
import time
FOLDERNAME = "LAW-OpenNMT-bert-0.8-" + str(time.strftime("%Y%m%d-%H%M"))
# !mkdir $FOLDERNAME

path = path + FOLDERNAME
os.chdir(path)
# !pwd

# import os
# path = '/content/drive/Shared drives/chinh-share/nmt-v3/OpenNMT-TED-EM-bert-ratio-8-2-2-20210128-0637'
# os.chdir(path)
# !pwd
# Out:
# /content/drive/Shared drives/chinh-share/nmt-v5-Faiss/LAW-OpenNMT-bert-0.8-20210411-0144

# %%
# !nvidia-smi
# Out:
# Sun Apr 11 01:44:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## **Install libraries**

# %%
# !pip install OpenNMT-py==1.2.0
# !pip install -U scikit-learn
# Out:
# Collecting OpenNMT-py==1.2.0
#   Downloading https://files.pythonhosted.org/packages/9f/20/40f8b722aa0e35e259c144b6ec2d684f1aea7de869cf586c67cfd6fe1c55/OpenNMT_py-1.2.0-py3-none-any.whl (195kB)
#      |████████████████████████████████| 204kB 6.1MB/s
# Collecting pyonmttok==1.*; platform_system == "Linux"
#   Downloading https://files.pythonhosted.org/packages/3f/63/17c6ac0d8a0cfa5ff7257e52edb6759d12dc266392f6c97f5c65c0c7238c/pyonmttok-1.25.0-cp37-cp37m-manylinux1_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 25.3MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (4.41.1)
# Collecting torchtext==0.4.0
#   Downloading https://files.pythonhosted.org/packages/43/94/929d6bd236a4fb5c435982a7eb9730b78dcd8659acf328fd2ef9de85f483/torchtext-0.4.0-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 9.7MB/s
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (1.15.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (1.8.1+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (0.16.0)
# Collecting configargparse
#   Downloading https://files.pythonhosted.org/packages/5d/c3/17846950db4e11cc2e71b36e5f8b236a7ab2f742f65597f3daf94f0b84b7/ConfigArgParse-1.4.tar.gz (45kB)
#      |████████████████████████████████| 51kB 8.6MB/s
# Collecting waitress
#   Downloading https://files.pythonhosted.org/packages/a8/cf/a9e9590023684dbf4e7861e261b0cfd6498a62396c748e661577ca720a29/waitress-2.0.0-py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 9.6MB/s
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py==1.2.0) (2.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0->OpenNMT-py==1.2.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0->OpenNMT-py==1.2.0) (1.19.5)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py==1.2.0) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py==1.2.0) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py==1.2.0) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py==1.2.0) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->OpenNMT-py==1.2.0) (3.7.4.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (0.12.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (0.36.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (3.12.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (54.2.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (1.28.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (0.4.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->OpenNMT-py==1.2.0) (1.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py==1.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py==1.2.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py==1.2.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py==1.2.0) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->flask->OpenNMT-py==1.2.0) (1.1.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py==1.2.0) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py==1.2.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py==1.2.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->OpenNMT-py==1.2.0) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=1.14->OpenNMT-py==1.2.0) (3.8.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py==1.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->OpenNMT-py==1.2.0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->OpenNMT-py==1.2.0) (3.4.1)
# Building wheels for collected packages: configargparse
#   Building wheel for configargparse (setup.py) ... done
#   Created wheel for configargparse: filename=ConfigArgParse-1.4-cp37-none-any.whl size=19638 sha256=efd9fe11e6a5353d957cfab1dc1e40f808a94b2c6dc28cec4e751d4766c23897
#   Stored in directory: /root/.cache/pip/wheels/d6/61/f7/626bbd080a9f2f70015f92025e0af663c595146083f3d9aa05
# Successfully built configargparse
# Installing collected packages: pyonmttok, torchtext, configargparse, waitress, OpenNMT-py
#   Found existing installation: torchtext 0.9.1
#     Uninstalling torchtext-0.9.1:
#       Successfully uninstalled torchtext-0.9.1
# Successfully installed OpenNMT-py-1.2.0 configargparse-1.4 pyonmttok-1.25.0 torchtext-0.4.0 waitress-2.0.0
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/f3/74/eb899f41d55f957e2591cde5528e75871f817d9fb46d4732423ecaca736d/scikit_learn-0.24.1-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 1.4MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.1 threadpoolctl-2.1.0

# %%
# !wget https://raw.githubusercontent.com/hoangtrungchinh/clc_data/master/dataset/law_bert.tar.gz
# !mkdir data_bin
# !tar -xvf 'law_bert.tar.gz'
# Out:
# --2021-04-11 01:44:26--  https://raw.githubusercontent.com/hoangtrungchinh/clc_data/master/dataset/law_bert.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4494433 (4.3M) [application/octet-stream]
# Saving to: ‘law_bert.tar.gz’
#
# law_bert.tar.gz     100%[===================>]   4.29M  16.1MB/s    in 0.3s
#
# 2021-04-11 01:44:26 (16.1 MB/s) - ‘law_bert.tar.gz’ saved [4494433/4494433]
#
# en_train_EM_score_0.95
# vi_valid
# en_train_EM_0.95
# en_train_EM_factor_0.85
# en_train_EM_score_0.8
# vi_train
# en_train_EM_factor_0.8
# en_train_EM_0.8
# en_valid
# en_train_EM_factor_0.95
# en_train
# en_train_EM_score_0.85
# vi_test
# en_train_EM_0.85
# en_train_EM_score_0.9
# en_test
# en_train_EM_factor_0.9
# en_train_EM_0.9

# %%
# !mkdir -p output
# !onmt_preprocess -train_src 'en_train_EM_0.8' \\
-train_tgt 'vi_train' \\
-valid_src 'en_valid' \\
-valid_tgt 'vi_valid' \\
-save_data 'output/en-vi'
# Out:
# [2021-04-11 01:44:30,600 INFO] Extracting features...
# [2021-04-11 01:44:30,602 INFO]  * number of source features: 0.
# [2021-04-11 01:44:30,602 INFO]  * number of target features: 0.
# [2021-04-11 01:44:30,602 INFO] Building `Fields` object...
# [2021-04-11 01:44:30,602 INFO] Building & saving training data...
# [2021-04-11 01:44:30,646 INFO] Building shard 0.
# [2021-04-11 01:44:31,190 INFO]  * saving 0th train data shard to output/en-vi.train.0.pt.
# [2021-04-11 01:44:31,721 INFO]  * tgt vocab size: 5072.
# [2021-04-11 01:44:31,740 INFO]  * src vocab size: 14167.
# [2021-04-11 01:44:31,984 INFO] Building & saving validation data...
# [2021-04-11 01:44:32,025 INFO] Building shard 0.
# [2021-04-11 01:44:32,059 INFO]  * saving 0th valid data shard to output/en-vi.valid.0.pt.

# %%
# !mkdir -p model
# !onmt_train -data 'output/en-vi' \\
-save_model 'model/en-vi' \\
-layers 6 -rnn_size 512 -word_vec_size 512 -transformer_ff 2048 -heads 8 \\
-encoder_type transformer -decoder_type transformer -position_encoding \\
-train_steps 30000  -max_generator_batches 2 -dropout 0.1 -batch_size 4096 \\
-batch_type tokens -normalization tokens  -accum_count 2 -optim adam -adam_beta2 0.998 \\
-decay_method noam -warmup_steps 8000 -learning_rate 2 -max_grad_norm 0 -param_init 0 \\
-param_init_glorot -label_smoothing 0.1 -valid_steps 1000 -save_checkpoint_steps 1000 \\
-report_every 1000 -world_size 1 -gpu_ranks 0
# Out:
# [2021-04-11 01:44:33,967 INFO]  * src vocab size = 14167
# [2021-04-11 01:44:33,967 INFO]  * tgt vocab size = 5072
# [2021-04-11 01:44:33,967 INFO] Building model...
# [2021-04-11 01:44:40,553 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(14167, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(5072, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer_layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=512, out_features=5072, bias=True)
#     (1): Cast()
#     (2): LogSoftmax(dim=-1)
#   )
# )
# [2021-04-11 01:44:40,624 INFO] encoder: 26168832
# [2021-04-11 01:44:40,624 INFO] decoder: 30424016
# [2021-04-11 01:44:40,625 INFO] * number of parameters: 56592848
# [2021-04-11 01:44:40,628 INFO] Starting training on GPU: [0]
# [2021-04-11 01:44:40,628 INFO] Start training loop and validate every 1000 steps...
# [2021-04-11 01:44:40,628 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:44:41,012 INFO] number of examples: 11493
# [2021-04-11 01:45:02,000 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:45:02,423 INFO] number of examples: 11493
# [2021-04-11 01:45:23,806 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:45:24,124 INFO] number of examples: 11493
# [2021-04-11 01:45:45,148 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:45:45,465 INFO] number of examples: 11493
# [2021-04-11 01:46:06,971 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:46:07,292 INFO] number of examples: 11493
# [2021-04-11 01:46:28,316 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:46:28,631 INFO] number of examples: 11493
# [2021-04-11 01:46:50,053 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:46:50,443 INFO] number of examples: 11493
# [2021-04-11 01:47:11,369 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:47:11,760 INFO] number of examples: 11493
# [2021-04-11 01:47:33,186 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:47:33,579 INFO] number of examples: 11493
# [2021-04-11 01:47:54,514 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:47:54,899 INFO] number of examples: 11493
# [2021-04-11 01:48:16,318 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:48:16,723 INFO] number of examples: 11493
# [2021-04-11 01:48:37,666 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:48:38,060 INFO] number of examples: 11493
# [2021-04-11 01:48:59,508 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:48:59,903 INFO] number of examples: 11493
# [2021-04-11 01:49:20,854 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:49:21,251 INFO] number of examples: 11493
# [2021-04-11 01:49:42,673 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:49:43,080 INFO] number of examples: 11493
# [2021-04-11 01:50:04,017 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:50:04,422 INFO] number of examples: 11493
# [2021-04-11 01:50:25,876 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:50:26,273 INFO] number of examples: 11493
# [2021-04-11 01:50:47,348 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:50:47,779 INFO] number of examples: 11493
# [2021-04-11 01:51:09,288 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:51:09,699 INFO] number of examples: 11493
# [2021-04-11 01:51:30,664 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:51:31,078 INFO] number of examples: 11493
# [2021-04-11 01:51:52,527 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:51:52,928 INFO] number of examples: 11493
# [2021-04-11 01:52:13,860 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01:52:14,270 INFO] number of examples: 11493
# [2021-04-11 01:52:15,802 INFO] Step 1000/30000; acc:  26.57; ppl: 70.91; xent: 4.26; lr: 0.00012; 10085/11901 tok/s;    455 sec
# [2021-04-11 01:52:15,803 INFO] Loading dataset from output/en-vi.valid.0.pt
# [2021-04-11 01:52:15,867 INFO] number of examples: 1797
# [2021-04-11 01:52:19,125 INFO] Validation perplexity: 19.2895
# [2021-04-11 01:52:19,125 INFO] Validation accuracy: 45.8279
# [2021-04-11 01:52:19,181 INFO] Saving checkpoint model/en-vi_step_1000.pt
# [2021-04-11 01:52:42,018 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 01
INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:26:46,227 INFO] number of examples: 11493
# [2021-04-11 05:27:07,667 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:27:08,104 INFO] number of examples: 11493
# [2021-04-11 05:27:19,181 INFO] Step 29000/30000; acc:  99.91; ppl:  1.01; xent: 0.01; lr: 0.00052; 9957/11752 tok/s;  13359 sec
# [2021-04-11 05:27:19,182 INFO] Loading dataset from output/en-vi.valid.0.pt
# [2021-04-11 05:27:19,246 INFO] number of examples: 1797
# [2021-04-11 05:27:22,515 INFO] Validation perplexity: 14.5138
# [2021-04-11 05:27:22,515 INFO] Validation accuracy: 64.883
# [2021-04-11 05:27:22,571 INFO] Saving checkpoint model/en-vi_step_29000.pt
# [2021-04-11 05:27:35,037 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:27:35,595 INFO] number of examples: 11493
# [2021-04-11 05:27:57,094 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:27:57,512 INFO] number of examples: 11493
# [2021-04-11 05:28:18,417 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:28:18,841 INFO] number of examples: 11493
# [2021-04-11 05:28:40,240 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:28:40,672 INFO] number of examples: 11493
# [2021-04-11 05:29:01,588 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:29:02,017 INFO] number of examples: 11493
# [2021-04-11 05:29:23,414 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:29:23,839 INFO] number of examples: 11493
# [2021-04-11 05:29:44,752 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:29:45,180 INFO] number of examples: 11493
# [2021-04-11 05:30:06,573 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:30:07,004 INFO] number of examples: 11493
# [2021-04-11 05:30:27,939 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:30:28,369 INFO] number of examples: 11493
# [2021-04-11 05:30:49,763 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:30:50,196 INFO] number of examples: 11493
# [2021-04-11 05:31:11,122 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:31:11,554 INFO] number of examples: 11493
# [2021-04-11 05:31:32,952 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:31:33,405 INFO] number of examples: 11493
# [2021-04-11 05:31:54,323 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:31:54,769 INFO] number of examples: 11493
# [2021-04-11 05:32:16,165 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:32:16,604 INFO] number of examples: 11493
# [2021-04-11 05:32:37,514 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:32:37,839 INFO] number of examples: 11493
# [2021-04-11 05:32:59,362 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:32:59,693 INFO] number of examples: 11493
# [2021-04-11 05:33:20,724 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:33:21,046 INFO] number of examples: 11493
# [2021-04-11 05:33:42,454 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:33:42,858 INFO] number of examples: 11493
# [2021-04-11 05:34:03,771 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:34:04,181 INFO] number of examples: 11493
# [2021-04-11 05:34:25,599 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:34:26,007 INFO] number of examples: 11493
# [2021-04-11 05:34:46,935 INFO] Loading dataset from output/en-vi.train.0.pt
# [2021-04-11 05:34:47,343 INFO] number of examples: 11493
# [2021-04-11 05:34:59,703 INFO] Step 30000/30000; acc:  99.91; ppl:  1.01; xent: 0.01; lr: 0.00051; 9958/11758 tok/s;  13819 sec
# [2021-04-11 05:34:59,704 INFO] Loading dataset from output/en-vi.valid.0.pt
# [2021-04-11 05:34:59,871 INFO] number of examples: 1797
# [2021-04-11 05:35:03,129 INFO] Validation perplexity: 14.606
# [2021-04-11 05:35:03,129 INFO] Validation accuracy: 64.7534
# [2021-04-11 05:35:03,185 INFO] Saving checkpoint model/en-vi_step_30000.pt

# %%
# !ls -al model model/
# Out:
# model:
# total 20522880
# -rw------- 1 root root 700513855 Apr 11 03:01 en-vi_step_10000.pt
# -rw------- 1 root root 700513855 Apr 11 01:52 en-vi_step_1000.pt
# -rw------- 1 root root 700513855 Apr 11 03:09 en-vi_step_11000.pt
# -rw------- 1 root root 700513855 Apr 11 03:16 en-vi_step_12000.pt
# -rw------- 1 root root 700513855 Apr 11 03:24 en-vi_step_13000.pt
# -rw------- 1 root root 700513855 Apr 11 03:32 en-vi_step_14000.pt
# -rw------- 1 root root 700513855 Apr 11 03:39 en-vi_step_15000.pt
# -rw------- 1 root root 700513855 Apr 11 03:47 en-vi_step_16000.pt
# -rw------- 1 root root 700513855 Apr 11 03:55 en-vi_step_17000.pt
# -rw------- 1 root root 700513855 Apr 11 04:02 en-vi_step_18000.pt
# -rw------- 1 root root 700513855 Apr 11 04:10 en-vi_step_19000.pt
# -rw------- 1 root root 700513855 Apr 11 04:18 en-vi_step_20000.pt
# -rw------- 1 root root 700513855 Apr 11 02:00 en-vi_step_2000.pt
# -rw------- 1 root root 700513855 Apr 11 04:26 en-vi_step_21000.pt
# -rw------- 1 root root 700513855 Apr 11 04:33 en-vi_step_22000.pt
# -rw------- 1 root root 700513855 Apr 11 04:41 en-vi_step_23000.pt
# -rw------- 1 root root 700513855 Apr 11 04:49 en-vi_step_24000.pt
# -rw------- 1 root root 700513855 Apr 11 04:56 en-vi_step_25000.pt
# -rw------- 1 root root 700513855 Apr 11 05:04 en-vi_step_26000.pt
# -rw------- 1 root root 700513855 Apr 11 05:12 en-vi_step_27000.pt
# -rw------- 1 root root 700513855 Apr 11 05:19 en-vi_step_28000.pt
# -rw------- 1 root root 700513855 Apr 11 05:27 en-vi_step_29000.pt
# -rw------- 1 root root 700513855 Apr 11 05:35 en-vi_step_30000.pt
# -rw------- 1 root root 700513855 Apr 11 02:07 en-vi_step_3000.pt
# -rw------- 1 root root 700513855 Apr 11 02:15 en-vi_step_4000.pt
# -rw------- 1 root root 700513855 Apr 11 02:23 en-vi_step_5000.pt
# -rw------- 1 root root 700513855 Apr 11 02:30 en-vi_step_6000.pt
# -rw------- 1 root root 700513855 Apr 11 02:38 en-vi_step_7000.pt
# -rw------- 1 root root 700513855 Apr 11 02:46 en-vi_step_8000.pt
# -rw------- 1 root root 700513855 Apr 11 02:53 en-vi_step_9000.pt
#
# model/:
# total 20522880
# -rw------- 1 root root 700513855 Apr 11 03:01 en-vi_step_10000.pt
# -rw------- 1 root root 700513855 Apr 11 01:52 en-vi_step_1000.pt
# -rw------- 1 root root 700513855 Apr 11 03:09 en-vi_step_11000.pt
# -rw------- 1 root root 700513855 Apr 11 03:16 en-vi_step_12000.pt
# -rw------- 1 root root 700513855 Apr 11 03:24 en-vi_step_13000.pt
# -rw------- 1 root root 700513855 Apr 11 03:32 en-vi_step_14000.pt
# -rw------- 1 root root 700513855 Apr 11 03:39 en-vi_step_15000.pt
# -rw------- 1 root root 700513855 Apr 11 03:47 en-vi_step_16000.pt
# -rw------- 1 root root 700513855 Apr 11 03:55 en-vi_step_17000.pt
# -rw------- 1 root root 700513855 Apr 11 04:02 en-vi_step_18000.pt
# -rw------- 1 root root 700513855 Apr 11 04:10 en-vi_step_19000.pt
# -rw------- 1 root root 700513855 Apr 11 04:18 en-vi_step_20000.pt
# -rw------- 1 root root 700513855 Apr 11 02:00 en-vi_step_2000.pt
# -rw------- 1 root root 700513855 Apr 11 04:26 en-vi_step_21000.pt
# -rw------- 1 root root 700513855 Apr 11 04:33 en-vi_step_22000.pt
# -rw------- 1 root root 700513855 Apr 11 04:41 en-vi_step_23000.pt
# -rw------- 1 root root 700513855 Apr 11 04:49 en-vi_step_24000.pt
# -rw------- 1 root root 700513855 Apr 11 04:56 en-vi_step_25000.pt
# -rw------- 1 root root 700513855 Apr 11 05:04 en-vi_step_26000.pt
# -rw------- 1 root root 700513855 Apr 11 05:12 en-vi_step_27000.pt
# -rw------- 1 root root 700513855 Apr 11 05:19 en-vi_step_28000.pt
# -rw------- 1 root root 700513855 Apr 11 05:27 en-vi_step_29000.pt
# -rw------- 1 root root 700513855 Apr 11 05:35 en-vi_step_30000.pt
# -rw------- 1 root root 700513855 Apr 11 02:07 en-vi_step_3000.pt
# -rw------- 1 root root 700513855 Apr 11 02:15 en-vi_step_4000.pt
# -rw------- 1 root root 700513855 Apr 11 02:23 en-vi_step_5000.pt
# -rw------- 1 root root 700513855 Apr 11 02:30 en-vi_step_6000.pt
# -rw------- 1 root root 700513855 Apr 11 02:38 en-vi_step_7000.pt
# -rw------- 1 root root 700513855 Apr 11 02:46 en-vi_step_8000.pt
# -rw------- 1 root root 700513855 Apr 11 02:53 en-vi_step_9000.pt

# %%
# !onmt_translate -model model/en-vi_step_30000.pt -src en_test -tgt vi_test -output predict.txt
# Out:
# [2021-04-11 05:35:10,638 INFO] Translating shard 0.
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:209: UserWarning: An output with one or more elements was resized since it had shape [150], which does not match the required output shape [30, 5].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /pytorch/aten/src/ATen/native/Resize.cpp:19.)
#   torch.mul(self.topk_scores, length_penalty, out=self.topk_log_probs)
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:209: UserWarning: An output with one or more elements was resized since it had shape [135], which does not match the required output shape [27, 5].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /pytorch/aten/src/ATen/native/Resize.cpp:19.)
#   torch.mul(self.topk_scores, length_penalty, out=self.topk_log_probs)
# [2021-04-11 05:42:42,408 INFO] PRED AVG SCORE: -0.3048, PRED PPL: 1.3564
# [2021-04-11 05:42:42,408 INFO] GOLD AVG SCORE: -2.6087, GOLD PPL: 13.5817

# %%
# !tail vi_test
# Out:
# Việc giải quyết tranh chấp lao động do cơ quan, tổ chức, cá nhân có thẩm quyền giải quyết tranh chấp lao động tiến hành sau khi một trong hai bên có đơn yêu cầu do một trong hai bên từ chối thương lượng, thương lượng nhưng không thành hoặc thương lượng thành nhưng một trong hai bên không thực hiện.
# Việc giám định do cá nhân hoặc do tập thể thực hiện.Giám định bổ sung
# Bầu, miễn nhiệm, bãi nhiệm Chủ tịch Hội đồng thành viên; quyết định bổ nhiệm, miễn nhiệm, bãi nhiệm, ký và chấm dứt hợp đồng đối với Giám đốc hoặc Tổng giám đốc, Kế toán trưởng và người quản lý khác quy định tại Điều lệ công ty;
# Người yêu cầu Tòa án Việt Nam công nhận và cho thi hành hoặc không công nhận tại Việt Nam bản án, quyết định dân sự của Tòa án nước ngoài; công nhận và cho thi hành phán quyết của Trọng tài nước ngoài phải nộp lệ phí theo quy định của pháp luật Việt Nam.
# Họ, tên Thẩm phán, Thư ký phiên tòa, Kiểm sát viên; họ, tên Thẩm phán, Kiểm sát viên dự khuyết (nếu có);
# Giới hạn trách nhiệm đối với người cứu hộ không hoạt động trên một tàu biển nào hoặc chỉ hoạt động trên chính tàu biển mà người đó đang cung cấp các dịch vụ cứu hộ hoặc liên quan đến nó được tính tương đương với một tàu 1.500 GT.
# Phương thức giải quyết tranh chấp.
# Thực hiện nhiệm vụ, quyền hạn khác trong kiểm sát hoạt động tư pháp theo quy định của Bộ luật tố tụng hình sự.
# Hàng giả có giá thành sản xuất 100.000.000 đồng trở lên;
# Khiếu kiện quyết định hành chính, hành vi hành chính của Ủy ban nhân dân cấp tỉnh, Chủ tịch Ủy ban nhân dân cấp tỉnh liên quan đến nhiều đối tượng;

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17114 (delta 7), reused 8 (delta 4), pack-reused 17085
# Receiving objects: 100% (17114/17114), 273.05 MiB | 24.54 MiB/s, done.
# Resolving deltas: 100% (12323/12323), done.
# Checking out files: 100% (228/228), done.

# %%
# !ls -al
# Out:
# total 22465
# drwx------  2 root root    4096 Apr 11 01:44 data_bin
# -rw-------  1 root root  257314 Apr 11 01:32 en_test
# -rw-------  1 root root 2096540 Apr 11 01:32 en_train
# -rw-------  1 root root 2564912 Apr 11 01:35 en_train_EM_0.8
# -rw-------  1 root root 2224075 Apr 11 01:35 en_train_EM_0.85
# -rw-------  1 root root 2137239 Apr 11 01:35 en_train_EM_0.9
# -rw-------  1 root root 2108457 Apr 11 01:35 en_train_EM_0.95
# -rw-------  1 root root  801412 Apr 11 01:35 en_train_EM_factor_0.8
# -rw-------  1 root root  688124 Apr 11 01:35 en_train_EM_factor_0.85
# -rw-------  1 root root  659440 Apr 11 01:35 en_train_EM_factor_0.9
# -rw-------  1 root root  650068 Apr 11 01:35 en_train_EM_factor_0.95
# -rw-------  1 root root  148555 Apr 11 01:35 en_train_EM_score_0.8
# -rw-------  1 root root  148555 Apr 11 01:35 en_train_EM_score_0.85
# -rw-------  1 root root  148555 Apr 11 01:35 en_train_EM_score_0.9
# -rw-------  1 root root  148555 Apr 11 01:35 en_train_EM_score_0.95
# -rw-------  1 root root  265528 Apr 11 01:32 en_valid
# -rw-------  1 root root 4494433 Apr 11 01:44 law_bert.tar.gz
# drwx------  2 root root    4096 Apr 11 05:35 model
# drwx------ 11 root root    4096 Apr 11 05:42 OpenNMT-py
# drwx------  2 root root    4096 Apr 11 01:44 output
# -rw-------  1 root root  239870 Apr 11 05:42 predict.txt
# -rw-------  1 root root  314903 Apr 11 01:32 vi_test
# -rw-------  1 root root 2560025 Apr 11 01:32 vi_train
# -rw-------  1 root root  325494 Apr 11 01:32 vi_valid

# %%
# !perl OpenNMT-py/tools/multi-bleu.perl vi_test < predict.txt
# Out:
# BLEU = 37.11, 69.1/55.2/45.2/38.2 (BP=0.732, ratio=0.762, hyp_len=39108, ref_len=51293)
